# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./data_files/data.csv")

# %%
df.rename(columns={'Index':'auto_od'}
# Out:
#     Index      Customer Id First Name Last Name  \
# 0       1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1       2  1Ef7b82A4CAAD10    Preston    Lozano
# 2       3  6F94879bDAfE5a6        Roy     Berry
# 3       4  5Cef8BFA16c5e3c      Linda     Olsen
# 4       5  053d585Ab6b3159     Joanna    Bender
# ..    ...              ...        ...       ...
# 95     96  cb8E23e48d22Eae       Karl     Greer
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer
# 99    100  2354a0E336A91A1   Clarence    Haynes
#
#                             Company               City  \
# 0                   Rasmussen Group       East Leonard
# 1                       Vega-Gentry  East Jimmychester
# 2                     Murillo-Perry      Isabelborough
# 3   Dominguez, Mcmillan and Donovan         Bensonview
# 4          Martin, Lang and Andrade     West Priscilla
# ...

# %%
list(df.columns)
# Out:
# ['Index',
#  'Customer Id',
#  'First Name',
#  'Last Name',
#  'Company',
#  'City',
#  'Country',
#  'Phone 1',
#  'Phone 2',
#  'Email',
#  'Subscription Date',
#  'Website',
#  'Numeric_Column']

# %%
df['Customer Id']
# Out:
# 0     DD37Cf93aecA6Dc
# 1     1Ef7b82A4CAAD10
# 2     6F94879bDAfE5a6
# 3     5Cef8BFA16c5e3c
# 4     053d585Ab6b3159
#            ...
# 95    cb8E23e48d22Eae
# 96    CeD220bdAaCfaDf
# 97    28CDbC0dFe4b1Db
# 98    c23d1D9EE8DEB0A
# 99    2354a0E336A91A1
# Name: Customer Id, Length: 100, dtype: object

# %%
df[['Customer Id']]
# Out:
#         Customer Id
# 0   DD37Cf93aecA6Dc
# 1   1Ef7b82A4CAAD10
# 2   6F94879bDAfE5a6
# 3   5Cef8BFA16c5e3c
# 4   053d585Ab6b3159
# ..              ...
# 95  cb8E23e48d22Eae
# 96  CeD220bdAaCfaDf
# 97  28CDbC0dFe4b1Db
# 98  c23d1D9EE8DEB0A
# 99  2354a0E336A91A1
#
# [100 rows x 1 columns]

# %%
df[['Customer Id','Website']]
# Out:
#         Customer Id                            Website
# 0   DD37Cf93aecA6Dc         http://www.stephenson.com/
# 1   1Ef7b82A4CAAD10              http://www.hobbs.com/
# 2   6F94879bDAfE5a6           http://www.lawrence.com/
# 3   5Cef8BFA16c5e3c         http://www.good-lyons.com/
# 4   053d585Ab6b3159        https://goodwin-ingram.com/
# ..              ...                                ...
# 95  cb8E23e48d22Eae            http://hayes-perez.com/
# 96  CeD220bdAaCfaDf         https://novak-allison.com/
# 97  28CDbC0dFe4b1Db              https://www.ross.com/
# 98  c23d1D9EE8DEB0A               http://watkins.info/
# 99  2354a0E336A91A1  http://www.hatfield-saunders.net/
#
# [100 rows x 2 columns]

# %%
df.head()
# Out:
#    Index      Customer Id First Name Last Name  \
# 0      1  DD37Cf93aecA6Dc     Sheryl    Baxter
# 1      2  1Ef7b82A4CAAD10    Preston    Lozano
# 2      3  6F94879bDAfE5a6        Roy     Berry
# 3      4  5Cef8BFA16c5e3c      Linda     Olsen
# 4      5  053d585Ab6b3159     Joanna    Bender
#
#                            Company               City  \
# 0                  Rasmussen Group       East Leonard
# 1                      Vega-Gentry  East Jimmychester
# 2                    Murillo-Perry      Isabelborough
# 3  Dominguez, Mcmillan and Donovan         Bensonview
# 4         Martin, Lang and Andrade     West Priscilla
#
#                       Country                 Phone 1                Phone 2  \
# 0                       Chile            229.077.5154       397.884.0519x718
# 1                    Djibouti              5153435776       686-620-1820x944
# 2         Antigua and Barbuda                   -1199    (496)978-3969x58947
# ...

# %%
df.tail()
# Out:
#     Index      Customer Id First Name Last Name                Company  \
# 95     96  cb8E23e48d22Eae       Karl     Greer              Carey LLC
# 96     97  CeD220bdAaCfaDf       Lynn  Atkinson  Ware, Burns and Oneal
# 97     98  28CDbC0dFe4b1Db       Fred    Guerra          Schmitt-Jones
# 98     99  c23d1D9EE8DEB0A     Yvonne    Farmer     Fitzgerald-Harrell
# 99    100  2354a0E336A91A1   Clarence    Haynes     Le, Nash and Cross
#
#                City          Country               Phone 1  \
# 95     East Richard           Guyana   (188)169-1674x58692
# 96     New Bradview        Sri Lanka                 -3769
# 97       Ortegaland  Solomon Islands  +1-753-067-8419x7170
# 98  Lake Elijahview            Aruba         (530)311-9786
# 99        Judymouth         Honduras         (753)813-6941
#
#                    Phone 2                           Email Subscription Date  \
# 95    001-841-293-3519x614                hhart@jensen.com        30-01-2022
# ...

# %%
df.describe()
# Out:
#             Index  Numeric_Column
# count  100.000000      100.000000
# mean    50.500000       52.510000
# std     29.011492       26.881519
# min      1.000000        1.000000
# 25%     25.750000       31.500000
# 50%     50.500000       52.500000
# 75%     75.250000       73.250000
# max    100.000000       98.000000

# %%
df.dtypes
# Out:
# Index                 int64
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# Numeric_Column        int64
# dtype: object

# %%
df['Index'] = df['Index'].astype(str)
# Out:
# 0       1
# 1       2
# 2       3
# 3       4
# 4       5
#      ...
# 95     96
# 96     97
# 97     98
# 98     99
# 99    100
# Name: Index, Length: 100, dtype: object

# %%
lst_of_columns = list(df.columns)

# %%
for i in lst_of_columns:
    if i in ['Phone 1','Phone 2','Company']:
        df[i] = df[i].astype(str)

# %%
df.dtypes
# Out:
# Index                object
# Customer Id          object
# First Name           object
# Last Name            object
# Company              object
# City                 object
# Country              object
# Phone 1              object
# Phone 2              object
# Email                object
# Subscription Date    object
# Website              object
# Numeric_Column       object
# dtype: object

# %%
type(df.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
df['Index'] = df['Index'].astype(float)

# %%
df['Subscription Date']=pd.to_datetime(df['Subscription Date'])
# Out:
# /var/folders/hv/v2yn6r8d6xx6zjxk3vfdpgdh0000gn/T/ipykernel_12510/3515405708.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Subscription Date']=pd.to_datetime(df['Subscription Date'])

# %%
df.dtypes
# Out:
# Index                       float64
# Customer Id                  object
# First Name                   object
# Last Name                    object
# Company                      object
# City                         object
# Country                      object
# Phone 1                      object
# Phone 2                      object
# Email                        object
# Subscription Date    datetime64[ns]
# Website                      object
# Numeric_Column               object
# dtype: object

# %%
df['Index'] = df['Index'].astype(int)
df['Index2'] = df['Index'].astype(int)

# %%
abc = df[['Index','Index2']]

# %%
abc.corr()
# Out:
#         Index  Index2
# Index     1.0     1.0
# Index2    1.0     1.0

# %% [markdown]
# 1. How to check null values in all columns
# 2. forward filling
# 3. backward filling
# 4. github and gitscm
# 5. use the excel file and convert all the graphs in python (matplotlib,plotly,seaborn)
# 6. what is inplace in pandas ?

# %%
df_students = pd.read_csv("students.csv")
df_professors = pd.read_csv("professors.csv")

# %%
def mul(fn,sn):
    return fn*sn

# %%
mul(fn=2,sn=3)
# Out:
# 6

# %%
df_students = df_students.rename(columns={'id_number':'id','Name':'name'})

# %%
df_students
# Out:
#     id               name  Age Gender
# 0  204        James Smith   26      M
# 1  202    Maria Rodriguez   22      F
# 2  264        David Smith   24      M
# 3  136    Patricia Garcia   21      F
# 4  238  Jessica Hernandez   25      F

# %%
df_professors
# Out:
#          Prof_name  id_number Department
# 0     Thomas Smith        204        ECE
# 1  Margaret Garcia        264         EE
# 2    James Johnson        108        CSE
# 3   Richard Miller        238         ME
# 4   Margaret MOORE        136         CE

# %%
pd.merge(df_students,df_professors,left_on=['id'],right_on=['id_number'],how='right')
# Out:
#       id             name   Age Gender        Prof_name  id_number Department
# 0  204.0      James Smith  26.0      M     Thomas Smith        204        ECE
# 1  264.0      David Smith  24.0      M  Margaret Garcia        264         EE
# 2    NaN              NaN   NaN    NaN    James Johnson        108        CSE
# 3    NaN              NaN   NaN    NaN   Richard Miller        238         ME
# 4  136.0  Patricia Garcia  21.0      F   Margaret MOORE        136         CE

# %%
df_students['id'] = np.where(df_students['id']==238,500,df_students['id'])

# %%
df_students
# Out:
#     id               name  Age Gender
# 0  204        James Smith   26      M
# 1  202    Maria Rodriguez   22      F
# 2  264        David Smith   24      M
# 3  136    Patricia Garcia   21      F
# 4  500  Jessica Hernandez   25      F
